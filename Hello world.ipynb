# %%
print('Hello world')
# Out:
# Hello world

# %%
opened_file = open('D:/DOCUMENTOS/Movimientos_Banco.csv')
from csv import reader
read_file = reader(opened_file)
apps_data = list(read_file)

# %%
print(apps_data)
# Out:
# [['Movimientos de la cuenta;;;;;;;;;;;;;;;;'], [';;;;;;;;;;;;;;;;'], ['Nº Cuenta / IBAN: ES92 2038 2468 5630 0057 1233;;;;;;;;;;;;;;;;'], ['Alias: LIBRETA FACIL;;;;;;;;;;;;;;;;'], [';;;;;;;;;;;;;;;;'], ['FECHA;Mes;FEC. VALOR;DESCRIPCIÓN;TIPO DE GASTO;IMPORTE;DIV.;SALDO;DIV.;ID;CONCEPTO 1;CONCEPTO 2;CONCEPTO 3;CONCEPTO 4;CONCEPTO 5;CONCEPTO 6;CONCEPTO 7'], ['16/07/2019;Julio;16/07/2019;EXPEDIDURIA TABACO;TABACO;-4', '6;EUR;1.097', '85;EUR;1;467;175311059050\xa0;485720******0674;COMPRA COMERCIO;EXPEDIDURIA TABACO 496;;'], ['16/07/2019;Julio;16/07/2019;LA FABRICA 21;COMER FUERA;-44', '2;EUR;1.042', '55;EUR;2;467;175128032050\xa0;485720******0674;COMPRA COMERCIO;LA FABRICA 21;;'], ['16/07/2019;Julio;16/07/2019;MAD GRILL;COMER FUERA;-11', '1;EUR;1.086', '75;EUR;3;467;327571212050\xa0;485720******0674;COMPRA COMERCIO;MAD GRILL;;'], ['15/07/2019;Julio;15/07/2019;FRUSURIOL SL;OTROS;-2', '2;EUR;1.171', '40;EUR;4;467;008922973050\xa0;485720******0674;COMPRA COMERCIO;FRUSURIOL SL;;'], ['15/07/2
# ...
